# %%
from linares_plot import *

# %%
# datos y plots originales en reviewer2_simulations
# df_std_d.to_excel('std_delay.xlsx')
# df_std.to_excel('std_stim.xlsx')
# df_delays.to_excel('rates_delay.xlsx')
# df_stims.to_excel('rates_stim.xlsx')

# %%
df_stims = pd.read_excel('rates_stim.xlsx')
df_std = pd.read_excel('std_stim.xlsx')

# %%
df_delays = pd.read_excel('rates_delay.xlsx')
df_std_d = pd.read_excel('std_delay.xlsx')

# %%
c_on = 'darkorange' #'#ff7f0e'
c_off = 'dodgerblue' #'#1f77b4'
c_on_exp = '#5a9c0b'

palette_ = [c_off, c_on]
palette_all = [c_off, c_on, c_on_exp]

# %% [markdown]
# # Delay

# %%
sns.lineplot(x='neuron', y='value', hue='condition', hue_order=['OFF', 'ON'], palette=palette_, data=df_delays )
plt.legend(frameon=False, prop={'size': 17})
plt.title('delay period')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('Rate (Hz)')
plt.xlabel('centered peak ($^\circ$)');
plt.ylim(-1,15);
plt.xlim(150,350);
plt.xticks([150, 200, 250, 300, 350], ['-70', '-35', '0', '35', '70']);
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lineplot(x='neuron', y='value', hue='condition', hue_order=['OFF', 'ON', 'ON exp.'], palette=palette_all, data=df_delays )
plt.legend(frameon=False, prop={'size': 17})
plt.title('delay period')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('Rate (Hz)')
plt.xlabel('centered peak ($^\circ$)');
plt.ylim(-1,15);
plt.xlim(150,350);
plt.xticks([150, 200, 250, 300, 350], ['-70', '-35', '0', '35', '70']);
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='condition', y='std fit', order=['OFF', 'ON', 'ON exp.'],  palette=palette_all, ci=95, data=df_std_d)
plt.title('delay period')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('std ($^\circ$)')
plt.xlabel('');
# plt.ylim(-1,15);
# plt.xlim(150,350);
plt.yticks([0, 0.1, 0.2, 0.3], [0, round(0.1*180/np.pi,1), round(0.2*180/np.pi,1), round(0.3*180/np.pi,1)]);
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Stim presentation

# %%
sns.lineplot(x='neuron', y='value', hue='condition', hue_order=['OFF', 'ON'], palette=palette_, data=df_stims)
plt.legend(frameon=False, prop={'size': 17})
plt.title('stimulus presentation')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('Rate (Hz)')
plt.xlabel('centered peak ($^\circ$)');
plt.ylim(-1,15);
plt.xlim(150,350);
plt.xticks([150, 200, 250, 300, 350], ['-70', '-35', '0', '35', '70']);
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lineplot(x='neuron', y='value', hue='condition', hue_order=['OFF', 'ON', 'ON exp.'], palette=palette_all, data=df_stims )
plt.legend(frameon=False, prop={'size': 17})
plt.title('stimulus presentation')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('Rate (Hz)')
plt.xlabel('centered peak ($^\circ$)');
plt.ylim(-1,15);
plt.xlim(150,350);
plt.xticks([150, 200, 250, 300, 350], ['-70', '-35', '0', '35', '70']);
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='condition', y='std fit', order=['OFF', 'ON', 'ON exp.'],  palette=palette_all, ci=95, data=df_std)
plt.title('stimulus presentation')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('std ($^\circ$)')
plt.xlabel('');
# plt.ylim(-1,15);
# plt.xlim(150,350);
plt.yticks([0, 0.1, 0.2, 0.3], [0, round(0.1*180/np.pi,1), round(0.2*180/np.pi,1), round(0.3*180/np.pi,1)]);
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from model_phantom_DB import *
from linares_plot import * 
import itertools

# %matplotlib inline
# %config InlineBackend.figure_format = 'png' ## 'svg'

# %load_ext autoreload
# %autoreload 2

# %%
n_simuls= 100 #100
numcores = multiprocessing.cpu_count() -1
print('Number cores: '+ str(numcores))

from scipy.optimize import curve_fit 

def gauss(x,mu,sigma,A):
        return A*exp(-(x-mu)**2/2/sigma**2)

N=512
# Out:
# Number cores: 7

# %%
### with n_simulus, each cell takes about 5 minutes
fee=1
fei=1
fie=1
fii=1

OFF = Parallel(n_jobs = numcores)(delayed(model)(totalTime=3000, targ_onset_1=100, targ_onset_2=1000, angle_target_i=90, presentation_period=100,
           angle_separation=170, tauE=20, tauI=10,  n_stims=2, I0E=-3.5, I0I=0.5, 
           GEE=0.068*fee,
           GII= 0.13*fii,
           GEI=0.13*fei,
           GIE=0.042*fie, 
           sigE=7., sigI=5., k_noise=0.6,            
           kappa_E=45, 
           kappa_I=0.3, 
           kappa_stim=40., N=512, stim_strengthE=9.4, stim_strengthI=0.,
           plot_connectivity=False, plot_rate=False, plot_hm=True , plot_fit=False, 
           phantom_st=1.2, phantom_onset=50000, phnatom_duration=100)  for n in range(n_simuls))

# %%
fee=1
fei=1
fie=1
fii=1

ON_E = Parallel(n_jobs = numcores)(delayed(model)(totalTime=3000, targ_onset_1=100, targ_onset_2=1000, angle_target_i=90, presentation_period=100,
           angle_separation=170, tauE=20, tauI=10,  n_stims=2, I0E=-3.5, I0I=0.5, 
           GEE=0.068*fee,
           GII= 0.13*fii,
           GEI=0.13*fei,
           GIE=0.042*fie, 
           sigE=7., sigI=5., k_noise=0.6,            
           kappa_E=45, 
           kappa_I=0.3, 
           kappa_stim=40., N=512, stim_strengthE=9.4, stim_strengthI=0.,
           plot_connectivity=False, plot_rate=False, plot_hm=True , plot_fit=False, 
           phantom_st=1.2+3.55, phantom_onset=50000, phnatom_duration=100)  for n in range(n_simuls))

# %%
fee=1
fei=1
fie=1
fii=1

ON = Parallel(n_jobs = numcores)(delayed(model)(totalTime=3000, targ_onset_1=100, targ_onset_2=1000, angle_target_i=90, presentation_period=100,
           angle_separation=170, tauE=20, tauI=10,  n_stims=2, I0E=0.05, I0I=0.5, 
           GEE=0.068*fee,
           GII= 0.13*fii,
           GEI=0.13*fei,
           GIE=0.042*fie, 
           sigE=7., sigI=5., k_noise=0.6,            
           kappa_E=45, 
           kappa_I=0.3, 
           kappa_stim=40., N=512, stim_strengthE=9.4, stim_strengthI=0.,
           plot_connectivity=False, plot_rate=False, plot_hm=True , plot_fit=False, 
           phantom_st=1.2, phantom_onset=50000, phnatom_duration=100)  for n in range(n_simuls))

# %%
#Palettes
print(sns.color_palette("tab10").as_hex())
sns.palplot(sns.color_palette("tab10"))
plt.show()
c_on = 'darkorange' #'#ff7f0e'
c_off = 'dodgerblue' #'#1f77b4'

onoff_pal=[c_on, c_off]
offon_pal = [c_off, c_on]

pal_cyan = sns.color_palette("RdBu_r", n_colors=200)[40:] #RdBu_r
ltc= 'gold'  #'springgreen'
lw_t=3
N=512
stimon = 50
stimoff = 50 + floor(100/2) ;


nsteps=int(floor(750));
p_targ2 = int((N * 90)/360)
p_dist = int((N * (90+57) )/360)
p_dist2 = int((N * (90+170) )/360)
sns.set_context("poster", font_scale=1.1)
sns.set_style("ticks")


def hemap(an, stimulation, order):
    dims=np.shape(an[4])
    stimon = 100/2
    stimoff = 100/2 + floor(100/2) ;
    stim2on = 1000/2
    stim2off = 1000/2 + floor(100/2) ;  
    
    RE_sorted=flipud(an[4])
    ax = sns.heatmap(RE_sorted, cmap=pal_cyan, vmin=0, vmax=18,  cbar=True, 
                cbar_kws={"shrink": .82, 'ticks' : [0, 6, 12, 18], 'label': 'rate (Hz)'})
    ax.figure.axes[-1].yaxis.label.set_size(15)
    plt.gca().set_ylabel('')
    plt.gca().set_xlabel('')
    plt.gca().set_title('')
    
    if order==1:
        plt.gca().plot([stimon, stimon+400], [p_targ2, p_targ2], ls='--', color =ltc, linewidth=3) 
    if order==2:
        plt.gca().plot([500, 900], [p_dist, p_dist], ls='--', color =ltc, linewidth=lw_t) 
    #   
    plt.gca().set_xticks([])
    plt.gca().set_xticklabels([])
    #
    plt.gca().set_yticks([0, N/4, N/2,  3*N/4, N ])
    #plt.gca().set_yticklabels(['0','','$^\pi$', '', '2$^\pi$'])
    plt.gca().set_yticklabels(['0','','180', '', '360'])
    
    plt.gca().set_xlabel('', fontsize=20);
    plt.gca().set_ylabel('neuron preferred ($^\circ$)', fontsize=20);
    plt.gca().set_ylim(570, -45)
    
    ##line stims       
    plt.plot([0, stimon], [-15, -15], 'k-', linewidth=3)
    #
    plt.plot([stimon, stimon], [-15, -40], 'k-', linewidth=3)
    plt.plot([stimon, stimoff], [-40, -40], 'k-', linewidth=3)
    plt.plot([stimoff, stimoff], [-15, -40], 'k-', linewidth=3)
    #
    plt.plot([stimoff, stim2on], [-15, -15], 'k-', linewidth=3)
    #
    plt.plot([stim2on, stim2on], [-15, -40], 'k-', linewidth=3)
    plt.plot([stim2on, stim2off], [-40, -40], 'k-', linewidth=3)
    plt.plot([stim2off, stim2off], [-15, -40], 'k-', linewidth=3)
    #
    plt.plot([stim2off, dims[1]], [-15, -15], 'k-', linewidth=3)
    #time
    plt.plot([dims[1]-500, dims[1]], [540, 540], 'k-', linewidth=3)
    plt.text(dims[1]-300, 600, '1s', fontsize=20)
    # stimulation
    if stimulation=='ON':
        plt.text(dims[1]-300, 70, stimulation, weight= 'heavy', color='w', fontsize=20)
    if stimulation=='OFF':
        plt.text(dims[1]-300, 70, stimulation, weight= 'heavy', color='k', fontsize=20)

# %%
import scipy
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
from scipy.stats import norm


def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))


def von_misses(x,a,mu,k):
        return a*(np.exp( k * np.cos(x-mu))) / (2*np.pi*scipy.special.i0(k))

# %%
frames_ON_delay = []

for s in range(len(ON)):
    ###
    #hemap(ON[s], 'ON', 1)
    ###
    rate_last_1s = ON[s][4][:, -500:].mean(axis=1)
    ###
    x = np.linspace(-pi, pi, N)
    y = rate_last_1s
    popt,pcov = curve_fit(von_misses,x,y)
    y_fit = von_misses(x,*popt)
    peaks, _ = find_peaks(y_fit)
    rolled_y = np.roll(y, -peaks[0] + int(N/2) ) 
    plt.figure()
    plt.plot(x, y, 'bo', markersize=2, label='raw')
    plt.plot(x, y_fit, 'ro', markersize=2, label='fit')
    plt.plot(x, rolled_y, 'go',  markersize=2, label='rolled')
    #plt.legend(frameon=False, loc=2)
    plt.show()
    dfx = pd.DataFrame({'rate': rolled_y, 'position':x, 'stimulation':'ON'})
    frames_ON_delay.append(dfx)

    
    
df_on_delay = pd.concat(frames_ON_delay)

# %%
frames_OFF_delay = []

for s in range(len(OFF)):
    ###
    #hemap(OFF[s], 'OFF', 1)
    ###
    rate_last_1s = OFF[s][4][:, -500:].mean(axis=1)
    ###
    x = np.linspace(-pi, pi, N)
    y = rate_last_1s
    popt,pcov = curve_fit(von_misses,x,y)
    y_fit = von_misses(x,*popt)
    peaks, _ = find_peaks(y_fit)
    rolled_y = np.roll(y, -peaks[0] + int(N/2) ) 
    plt.figure()
    plt.plot(x, y, 'bo', markersize=2, label='raw')
    plt.plot(x, y_fit, 'ro', markersize=2, label='fit')
    plt.plot(x, rolled_y, 'go',  markersize=2, label='rolled')
    #plt.legend(frameon=False, loc=2)
    plt.show()
    dfx = pd.DataFrame({'rate': rolled_y, 'position':x, 'stimulation':'OFF'})
    frames_OFF_delay.append(dfx)

    
    
df_off_delay = pd.concat(frames_OFF_delay)

# %%
frames_ONE_delay = []

for s in range(len(ON_E)):
    ###
    #hemap(ON_E[s], 'ON', 1)
    ###
    rate_last_1s = ON_E[s][4][:, -500:].mean(axis=1)
    ###
    x = np.linspace(-pi, pi, N)
    y = rate_last_1s
    popt,pcov = curve_fit(von_misses,x,y)
    y_fit = von_misses(x,*popt)
    peaks, _ = find_peaks(y_fit)
    rolled_y = np.roll(y, -peaks[0] + int(N/2) ) 
    plt.figure()
    plt.plot(x, y, 'bo', markersize=2, label='raw')
    plt.plot(x, y_fit, 'ro', markersize=2, label='fit')
    plt.plot(x, rolled_y, 'go',  markersize=2, label='rolled')
    #plt.legend(frameon=False, loc=2)
    plt.show()
    dfx = pd.DataFrame({'rate': rolled_y, 'position':x, 'stimulation':'ON exp.'})
    frames_ONE_delay.append(dfx)

    
    
df_onE_delay = pd.concat(frames_ONE_delay)

# %%
sns.lineplot(x='position', y='rate', color=c_on, data=df_on_delay )
sns.lineplot(x='position', y='rate', ci=69, color=c_off, data=df_off_delay )
sns.lineplot(x='position', y='rate', color=c_on_exp, data=df_onE_delay )

plt.legend(frameon=False, prop={'size': 17})
plt.title('delay')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('Rate (Hz)')
plt.xlabel('preferred ($^\circ$)');
plt.ylim(-2,18);
plt.yticks([0,6,12,18])
plt.xlim(-pi,pi);
plt.xticks([-pi, -pi/2, 0, pi/2, pi], ['-180', '-90', '0', '90', '180']);

# %%
frames_ON_stim = []

for s in range(len(ON)):
    ###
    #hemap(ON[s], 'ON', 1)
    ###
    rate_last_1s = ON[s][4][:, 50:100].mean(axis=1)
    ###
    x = np.linspace(-pi, pi, N)
    y = rate_last_1s
    popt,pcov = curve_fit(von_misses,x,y)
    y_fit = von_misses(x,*popt)
    peaks, _ = find_peaks(y_fit)
    rolled_y = np.roll(y, -peaks[0] + int(N/2) ) 
    plt.figure()
    plt.plot(x, y, 'bo', markersize=2, label='raw')
    plt.plot(x, y_fit, 'ro', markersize=2, label='fit')
    plt.plot(x, rolled_y, 'go',  markersize=2, label='rolled')
    #plt.legend(frameon=False, loc=2)
    plt.show()
    dfx = pd.DataFrame({'rate': rolled_y, 'position':x, 'stimulation':'ON'})
    frames_ON_stim.append(dfx)

    
    
df_on_stim = pd.concat(frames_ON_stim)

# %%
frames_OFF_stim = []

for s in range(len(OFF)):
    ###
    #hemap(OFF[s], 'OFF', 1)
    ###
    rate_last_1s = OFF[s][4][:, 50:100].mean(axis=1)
    ###
    x = np.linspace(-pi, pi, N)
    y = rate_last_1s
    popt,pcov = curve_fit(von_misses,x,y)
    y_fit = von_misses(x,*popt)
    peaks, _ = find_peaks(y_fit)
    rolled_y = np.roll(y, -peaks[0] + int(N/2) ) 
    plt.figure()
    plt.plot(x, y, 'bo', markersize=2, label='raw')
    plt.plot(x, y_fit, 'ro', markersize=2, label='fit')
    plt.plot(x, rolled_y, 'go',  markersize=2, label='rolled')
    #plt.legend(frameon=False, loc=2)
    plt.show()
    dfx = pd.DataFrame({'rate': rolled_y, 'position':x, 'stimulation':'OFF'})
    frames_OFF_stim.append(dfx)

    
    
df_off_stim = pd.concat(frames_OFF_stim)

# %%
frames_ONE_stim = []

for s in range(len(ON)):
    ###
    #hemap(ON_E[s], 'ON', 1)
    ###
    rate_last_1s = ON_E[s][4][:, 50:100].mean(axis=1)
    ###
    x = np.linspace(-pi, pi, N)
    y = rate_last_1s
    popt,pcov = curve_fit(von_misses,x,y)
    y_fit = von_misses(x,*popt)
    peaks, _ = find_peaks(y_fit)
    rolled_y = np.roll(y, -peaks[0] + int(N/2) ) 
    plt.figure()
    plt.plot(x, y, 'bo', markersize=2, label='raw')
    plt.plot(x, y_fit, 'ro', markersize=2, label='fit')
    plt.plot(x, rolled_y, 'go',  markersize=2, label='rolled')
    #plt.legend(frameon=False, loc=2)
    plt.show()
    dfx = pd.DataFrame({'rate': rolled_y, 'position':x, 'stimulation':'ON exp.'})
    frames_ONE_stim.append(dfx)

    
    
df_onE_stim = pd.concat(frames_ONE_stim)

# %%
sns.lineplot(x='position', y='rate', color=c_on, data=df_on_stim )
sns.lineplot(x='position', y='rate', color=c_off, data=df_off_stim )
sns.lineplot(x='position', y='rate', color=c_on_exp, data=df_onE_stim )

plt.legend(frameon=False, prop={'size': 17})
plt.title('stim presentation')
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('Rate (Hz)')
plt.xlabel('centered peak ($^\circ$)');
plt.ylim(-2,18);
plt.yticks([0,6,12,18])
plt.xlim(-pi,pi);
plt.xticks([-pi, -pi/2, 0, pi/2, pi], ['-180', '-90', '0', '90', '180']);
